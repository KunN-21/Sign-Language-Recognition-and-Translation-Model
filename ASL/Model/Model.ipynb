# %%
import pandas as pd
import joblib
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("../data/hand_landmarks.csv")
X = df.drop(['label', 'image_path'], axis=1).to_numpy()
le = LabelEncoder()
y = le.fit_transform(df['label'])
y_cat = to_categorical(y)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_cat, test_size=0.1, stratify=y, random_state=42)

model = Sequential([
    Dense(256, activation='tanh', input_shape=(X_train.shape[1],)),
    Dense(128, activation='tanh'),
    Dense(y_cat.shape[1], activation='softmax') 
])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# EarlyStopping: dừng sớm nếu val_loss không cải thiện 10 epoch liên tiếp
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True, # lấy lại trọng số tốt nhất
    verbose=1
)
# (Tuỳ chọn) Lưu model tốt nhất vào file
model_ckpt = ModelCheckpoint(
    "best_sign_classifier.keras",
    monitor='val_loss',
    save_best_only=True,
)

# Train the model
history = model.fit(
    X_train, y_train,
    epochs=40,
    batch_size=128,
    validation_split=0.2,
    callbacks=[early_stop, model_ckpt]
)
# Out:
# Epoch 1/40
# c:\Users\ADMIN\miniconda3\envs\myML\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7279 - loss: 1.1736 - val_accuracy: 0.9639 - val_loss: 0.1783
# Epoch 2/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9645 - loss: 0.1616 - val_accuracy: 0.9755 - val_loss: 0.1172
# Epoch 3/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9741 - loss: 0.1110 - val_accuracy: 0.9788 - val_loss: 0.1026
# Epoch 4/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9778 - loss: 0.0918 - val_accuracy: 0.9814 - val_loss: 0.0862
# Epoch 5/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9820 - loss: 0.0769 - val_accuracy: 0.9833 - val_loss: 0.0734
# Epoch 6/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9850 - loss: 0.0620 - val_accuracy: 0.9841 - val_loss: 0.0662
# Epoch 7/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9840 - loss: 0.0599 - val_accuracy: 0.9846 - val_loss: 0.0662
# Epoch 8/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9861 - loss: 0.0523 - val_accuracy: 0.9855 - val_loss: 0.0605
# Epoch 9/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9864 - loss: 0.0504 - val_accuracy: 0.9844 - val_loss: 0.0588
# Epoch 10/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9890 - loss: 0.0435 - val_accuracy: 0.9864 - val_loss: 0.0548
# Epoch 11/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9892 - loss: 0.0401 - val_accuracy: 0.9854 - val_loss: 0.0565
# Epoch 12/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9900 - loss: 0.0371 - val_accuracy: 0.9867 - val_loss: 0.0519
# Epoch 13/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9911 - loss: 0.0326 - val_accuracy: 0.9874 - val_loss: 0.0525
# Epoch 14/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9913 - loss: 0.0327 - val_accuracy: 0.9892 - val_loss: 0.0462
# Epoch 15/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9923 - loss: 0.0296 - val_accuracy: 0.9875 - val_loss: 0.0482
# Epoch 16/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9913 - loss: 0.0320 - val_accuracy: 0.9887 - val_loss: 0.0480
# Epoch 17/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9921 - loss: 0.0258 - val_accuracy: 0.9887 - val_loss: 0.0452
# Epoch 18/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9945 - loss: 0.0218 - val_accuracy: 0.9842 - val_loss: 0.0559
# Epoch 19/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9944 - loss: 0.0221 - val_accuracy: 0.9879 - val_loss: 0.0455
# Epoch 20/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9946 - loss: 0.0200 - val_accuracy: 0.9889 - val_loss: 0.0471
# Epoch 21/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9941 - loss: 0.0199 - val_accuracy: 0.9902 - val_loss: 0.0402
# Epoch 22/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9944 - loss: 0.0196 - val_accuracy: 0.9864 - val_loss: 0.0503
# Epoch 23/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9931 - loss: 0.0223 - val_accuracy: 0.9890 - val_loss: 0.0456
# Epoch 24/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9965 - loss: 0.0139 - val_accuracy: 0.9892 - val_loss: 0.0461
# Epoch 25/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9967 - loss: 0.0128 - val_accuracy: 0.9889 - val_loss: 0.0459
# Epoch 26/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9965 - loss: 0.0133 - val_accuracy: 0.9904 - val_loss: 0.0437
# Epoch 27/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9957 - loss: 0.0146 - val_accuracy: 0.9889 - val_loss: 0.0455
# Epoch 28/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9940 - loss: 0.0201 - val_accuracy: 0.9906 - val_loss: 0.0421
# Epoch 29/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9971 - loss: 0.0116 - val_accuracy: 0.9888 - val_loss: 0.0458
# Epoch 30/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9969 - loss: 0.0110 - val_accuracy: 0.9909 - val_loss: 0.0419
# Epoch 31/40
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9972 - loss: 0.0101 - val_accuracy: 0.9902 - val_loss: 0.0411
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 21.

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test accuracy: {test_acc}')

#f1 score
y_pred = model.predict(X_test)
y_pred = y_pred.argmax(axis=1)
y_test = y_test.argmax(axis=1)
f1 = f1_score(y_test, y_pred, average='weighted')
print(f'F1 score: {f1}')
# Out:
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9896 - loss: 0.0428
# Test accuracy: 0.9897326827049255
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# F1 score: 0.989739731124256

# %%
scaler_filename = "sign_scaler.pkl"

joblib.dump(scaler, scaler_filename)
le_filename = "sign_label_encoder.pkl"
joblib.dump(le, le_filename)
# Out:
# ['sign_label_encoder.pkl']

# %%
# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 8))
class_labels = [str(c) for c in le.classes_]
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# Tính tổng số nhầm lẫn giữa các cặp lớp (ngoại trừ đường chéo chính)

confused_pairs = []
for i in range(len(class_labels)):
    for j in range(len(class_labels)):
        if i != j and cm[i, j] > 0:
            confused_pairs.append(((class_labels[i], class_labels[j]), cm[i, j]))

# Sắp xếp giảm dần theo số lần nhầm lẫn
confused_pairs_sorted = sorted(confused_pairs, key=lambda x: x[1], reverse=True)

# Hiển thị top 10 cặp dễ nhầm lẫn nhất
print("Top các cặp từ dễ bị nhầm lẫn nhất:")
for (true_label, pred_label), count in confused_pairs_sorted[:10]:
    print(f"{true_label} ↔ {pred_label}: {count} lần")
# Out:
# Top các cặp từ dễ bị nhầm lẫn nhất:
# N ↔ M: 3 lần
# R ↔ U: 3 lần
# E ↔ S: 2 lần
# M ↔ N: 2 lần
# S ↔ X: 2 lần
# W ↔ V: 2 lần
# X ↔ U: 2 lần
# Z ↔ A: 2 lần
# del ↔ N: 2 lần
# A ↔ K: 1 lần
